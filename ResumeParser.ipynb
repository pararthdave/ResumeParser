# %% [markdown]
# <a href="https://colab.research.google.com/github/pararthdave/ResumeParser/blob/main/ResumeParser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pypdf2
# Out:
# ...
#      |████████████████████████████████| 77 kB 4.7 MB/s
# ...
#   Created wheel for pypdf2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61102 sha256=0bdfb198977cca9e85efefb53410811c495fb66539a81b90daac49104b410e86
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built pypdf2
# ...

# %%
# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
# ...

# %%
# !pip install pdftotext
# Out:
# ...
#      |████████████████████████████████| 113 kB 16.1 MB/s
# ...
#   Created wheel for pdftotext: filename=pdftotext-2.2.2-cp37-cp37m-linux_x86_64.whl size=54923 sha256=8203b3d16538363749e7c09e93fefc8104401999d3204b7c9584dafd2f6c4c4f
#   Stored in directory: /root/.cache/pip/wheels/98/19/8e/e8648026db8b7ef3324ad9afa1f7c9109a7e7509846f693ed9
# Successfully built pdftotext
# ...

# %%
# !cp -rv /content/drive/MyDrive/ResumeParser/Dataset/dataset.zip .
# Out:
# '/content/drive/MyDrive/ResumeParser/Dataset/dataset.zip' -> './dataset.zip'

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: dataset/Harika Sonnathi Resume 2022 2.pdf
#   inflating: dataset/KetanPawarResume.pdf
#   inflating: dataset/Mandar bhoir Resume (1)_compressed.pdf
#   inflating: dataset/pararthdave_Resume.pdf
#   inflating: dataset/Priyanka_RaikwarRESUME.pdf
#   inflating: dataset/priyanka_resume(8).pdf
#   inflating: dataset/ravisatvik.192_Resume.pdf
#   inflating: dataset/YOGAPRIYA H_RESUME.pdf

# %%
#importing libraries
import PyPDF2
import spacy
from spacy.matcher import Matcher,PhraseMatcher
import pdftotext
import pandas as pd
import os

# %%
! python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 9.8 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
path='/content/dataset' #file path for corpus
files = [os.path.join (path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
pdfs = []
for i in files:
    pdfs.append(i)

merger = PyPDF2.PdfFileMerger(strict=False)

for pdf in pdfs:
    merger.append(pdf)

merger.write("final.pdf")

# reader = PyPDF2.PdfFileReader('final.pdf', strict=False)
# page = reader.getNumPages()
# count = 0
# text = []
# while count < page:    
#     pageObj = reader.getPage(count)
#     count +=1
#     t = pageObj.extractText().strip()
#     text.append(t)
# print(text[3])

# %%
with open("final.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
finalpg=[]
for page in pdf:
    pg=page.strip()
    finalpg.append(pg)
print(finalpg[10])
# Out:
# MANDAR BHOIR
#                                  PERSONAL DETAILS
#                                   Mobile: 9623064007                 Date of birth : 19th April 2000
#                                   Address : S.NO.176/7, "Om niwas",  Email:
#                                   near bhekarainagar pmt bus depot,  bhoirmandar007@gmail.com
#                                   hadapsar, pune-412308
#                                   TECHNICAL SKILLS
# CARRIER OBJECTIVE
#                                   Operating system : Windows XP, Windows 7, Windows 10
#  A highly organized and hard-     Languages : C , HTML , Css, SQL, Python
# working individual looking for a
# responsible position to gain      Database software : Mysql
# practical experience.
#                                   Frameworks : Bootstrap
# To make use of my
# interpersonal skills to achieve   Platforms and software : Jupyter notebook, Vs code, Autocad
# goals of a company that
# ...

# %%
# load pre-trained model
nlp = spacy.load('en_core_web_sm')

# initialize matcher with a vocab
matcher = Matcher(nlp.vocab)

def extract_name(resume_text):
    nlp_text = nlp(resume_text)
    
    # First name and Last name are always Proper Nouns
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
    
    matcher.add('NAME', [pattern])
    
    matches = matcher(nlp_text)
    
    for match_id, start, end in matches:
        span = nlp_text[start:end]
        return span.text

# %%
for i in finalpg:
  print(extract_name(i))
# Out:
# Data Scientist
# YOGAPRIYA HARIBASKAR
# Pararth Dave
# Project Fidget
# Book Store
# SAS Certified
# Shivasthali Colony
# Priyanka Raikwar
# Sonnathi Harika
# Ketan Pawar
# PERSONAL DETAILS

# %%
import re
matcher1=Matcher(nlp.vocab)
def extract_socialmedia(resume_text):
    urls = re.findall(r'linkedin.com/i?n?/?[\w\.-]+', resume_text)
    return urls

# %%
for i in finalpg:
  print(extract_socialmedia(i))
# Out:
# ['linkedin.com/ravi-gorthi']
# ['linkedin.com/in/yogapriya-']
# []
# []
# []
# []
# []
# []
# ['linkedin.com/in/harika-sonnathi']
# ['linkedin.com/in/ketan-']
# []

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(finalpg[1])


for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# YOGAPRIYA YOGAPRIYA PROPN NNP compound XXXX True False
# HARIBASKAR HARIBASKAR PROPN NNP ROOT XXXX True False
#
#
#         SPACE _SP
#      False False
# +91 +91 NUM CD ROOT +dd False False
# 7010842961 7010842961 NUM CD nummod dddd False False
#                                     SPACE _SP       False False
# yogapriyaharibaskar1806@gmai yogapriyaharibaskar1806@gmai PROPN NNP ROOT xxxxdddd@xxxx False False
#             SPACE _SP       False False
# Namakkal Namakkal PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# India India PROPN NNP intj Xxxxx True False
#                             SPACE _SP       False False
# www.linkedin.com/in/yogapriya- www.linkedin.com/in/yogapriya- PROPN NNP conj xxx.xxxx.xxx/xx/xxxx- False False
#
#
#                                         SPACE _SP
#      False False
# l.com l.com PROPN NNP ROOT x.xxx False False
# ...
