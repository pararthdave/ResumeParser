# %% [markdown]
# <a href="https://colab.research.google.com/github/pararthdave/ResumeParser/blob/Priyanka/Resume_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 3.1 MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61102 sha256=320834760036df3410b80bdc744ea9c2b84da2150fbd776e4f04acf35c0e848c
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
#   cuda-nsight-compute-10-1 cuda-nsight-compute-11-0 cuda-nsight-compute-11-1
#   cuda-nsight-systems-10-1 cuda-nsight-systems-11-0 cuda-nsight-systems-11-1
#   cuda-nvcc-10-0 cuda-nvcc-10-1 cuda-nvcc-11-0 cuda-nvdisasm-10-0
#   cuda-nvdisasm-10-1 cuda-nvdisasm-11-0 cuda-nvml-dev-10-0 cuda-nvml-dev-10-1
#   cuda-nvml-dev-11-0 cuda-nvprof-10-0 cuda-nvprof-10-1 cuda-nvprof-11-0
#   cuda-nvprune-10-0 cuda-nvprune-10-1 cuda-nvprune-11-0 cuda-nvtx-10-0
#   cuda-nvtx-10-1 cuda-nvtx-11-0 cuda-nvvp-10-0 cuda-nvvp-10-1 cuda-nvvp-11-0
#   cuda-nvvp-11-1 cuda-samples-10-0 cuda-samples-10-1 cuda-samples-11-0
#   cuda-samples-11-1 cuda-sanitizer-11-0 cuda-sanitizer-api-10-1
#   cuda-toolkit-10-0 cuda-toolkit-10-1 cuda-toolkit-11-0 cuda-toolkit-11-1
#   cuda-tools-10-0 cuda-tools-10-1 cuda-tools-11-0 cuda-tools-11-1
#   cuda-visual-tools-10-0 cuda-visual-tools-10-1 cuda-visual-tools-11-0
#   cuda-visual-tools-11-1 default-jre dkms freeglut3 freeglut3-dev
#   keyboard-configuration libargon2-0 libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfontenc1 libidn11 libip4tc0 libjansson4
#   libnvidia-cfg1-510 libnvidia-common-460 libnvidia-common-510
#   libnvidia-extra-510 libnvidia-fbc1-510 libnvidia-gl-510 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2
#   libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0 libxtst6
#   nsight-compute-2020.2.1 nsight-compute-2022.1.0 nsight-systems-2020.3.2
#   nsight-systems-2020.3.4 nsight-systems-2021.5.2 nvidia-dkms-510
#   nvidia-kernel-common-510 nvidia-kernel-source-510 nvidia-modprobe
#   nvidia-settings openjdk-11-jre policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils
#   xserver-common xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-510
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libpoppler-cpp0v5
# The following NEW packages will be installed:
#   libpoppler-cpp-dev libpoppler-cpp0v5
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 36.7 kB of archives.
# After this operation, 188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp0v5 amd64 0.62.0-2ubuntu2.12 [28.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp-dev amd64 0.62.0-2ubuntu2.12 [8,676 B]
# Fetched 36.7 kB in 0s (81.1 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpoppler-cpp0v5:amd64.
# (Reading database ... 155113 files and directories currently installed.)
# Preparing to unpack .../libpoppler-cpp0v5_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Selecting previously unselected package libpoppler-cpp-dev:amd64.
# Preparing to unpack .../libpoppler-cpp-dev_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !pip install pdftotext
# Out:
# Collecting pdftotext
#   Downloading pdftotext-2.2.2.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 5.5 MB/s
# Building wheels for collected packages: pdftotext
#   Building wheel for pdftotext (setup.py) ... done
#   Created wheel for pdftotext: filename=pdftotext-2.2.2-cp37-cp37m-linux_x86_64.whl size=54910 sha256=14951a7dc22cf2ee9153ff81043df5fd710fe8bbf883df961aced985a0660aa4
#   Stored in directory: /root/.cache/pip/wheels/98/19/8e/e8648026db8b7ef3324ad9afa1f7c9109a7e7509846f693ed9
# Successfully built pdftotext
# Installing collected packages: pdftotext
# Successfully installed pdftotext-2.2.2

# %%
# !cp -rv /content/drive/MyDrive/DATASET .
# Out:
# '/content/drive/MyDrive/DATASET' -> './DATASET'
# '/content/drive/MyDrive/DATASET/PriyankaRaikwarRESUME.pdf' -> './DATASET/PriyankaRaikwarRESUME.pdf'

# %%
import PyPDF2
import spacy
from spacy.matcher import Matcher
import pdftotext
import pandas as pd
import os

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.5 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.10.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
path='/content/DATASET' #file path for corpus
files = [os.path.join (path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
pdfs = []
for i in files:
    pdfs.append(i)

merger = PyPDF2.PdfFileMerger(strict=False)

for pdf in pdfs:
    merger.append(pdf)

merger.write("final.pdf")

# %%
with open("final.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
finalpg=[]
for page in pdf:
    pg=page.strip()
    finalpg.append(pg)
print(finalpg[0])
# Out:
# PRIYANKA RAIKWAR
# CONTACT                                OBJECTIVE
# H.No:33 Shivasthali Colony, Makronia   To Secure a position where I can efficiently contribute my skills
# Sagar.                                 and abilities to the growth of organization and build my
# 7974849362                             professional career.
# Priyankajma17@gmail.com
# EDUCATION                              PROJECTS
# MNNIT ALLAHABAD, PRAYAGRAJ             LIBRARY MANAGEMENT SYSTEM | JAVA | MySQL
# Master of Computer Applications        -2019
#                                        • Students and admin can login with username and password.
# CPI: 8.87 (Till 5th sem)         -2022
#                                        • Admin can add books in database with unique book id.
# Dr. HARI SINGH GOUR UNIVERSITY |       • Registered students details are available.
# SAGAR                                  • Admin can check statistics of issued and returned book.
# Bachelor of Computer Applications      • Calculate fine for returning the book late.
# CGPA:9.12                        -2018
# D.M.A SAGAR                            VIDEO CONTROLLING BY HAND GESTURE | PYTHON
# CLASS XII | CBSE                       -2021
# Percentage: 71.4%                -2015 • Libraries used are OpenCV and NumPy.
#                                        • Web camera will detect the hand gesture & respond corresponding
# D.M.A SAGAR                            to it.
# CLASS X | CBSE                         • Operation included Pause, play, volume up- down and fast forward.
# CGPA: 8.0                        -2013
#                                        FIND VACCINATION SLOT | PYTHON | JSON
#                                        -2021
#                                        • Using the Pycharm platform and Postman.
#                                        • Can check vaccinations slots by PIN code and date.
# AREA OF INTEREST                       SKILLS
#        Data structure and Algorithm   PROGRAMMING:
#                                        Familiar with: C/C++, MySQL
#        DBMS                           Basics:         Java, Python , HTML, MongoDB
#        Operating system
#                                        TECHNICAL:
#                                        Familiar with: Anaconda, Postman, Net beans, Visual Studio.
#                                        ACHIEVEMENTS
#  HOBBIES                               ● Certificate of Completion of “ Certified Network Security
#        To explore new technologies.   Specialist(2020)” by(ICSI)
#        To read chronicles of freedom  ● Member of Volleyball team(2019) at MNNIT Allahabad
#         fighters.                      ● Got a gold medal in kabaddi (2019) at MNNIT Allahabad.
#        Drawing and Sketching          ● Worked as Class Representative in BCA.
#                                        ● Got second position in National Science Day(2017) Event

# %%
# load pre-trained model
nlp = spacy.load('en_core_web_sm')

# initialize matcher with a vocab
matcher = Matcher(nlp.vocab, validate=True)

def extract_name(resume_text):
    nlp_text = nlp(resume_text)
    
    # First name and Last name are always Proper Nouns
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
    
    matcher.add('NAME', None, [pattern])
    
    matches = matcher(nlp_text)
    
    for match_id, start, end in matches:
        span = nlp_text[start:end]
        return span.text

# %%
extract_name(finalpg[0])
# Out:
# ---------------------------------------------------------------------------
# MatchPatternError                         Traceback (most recent call last)
# <ipython-input-13-eb27e614b403> in <module>()
# ----> 1 extract_name(finalpg[0])
#
# <ipython-input-12-91541c414182> in extract_name(resume_text)
#      11     pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
#      12
# ---> 13     matcher.add('NAME', None, [pattern])
#      14
#      15     matches = matcher(nlp_text)
#
# matcher.pyx in spacy.matcher.matcher.Matcher.add()
#
# MatchPatternError: Invalid token patterns for matcher rule 'NAME'
#
# Pattern 0:
# - [{'POS': 'PROPN'}, {'POS': 'PROPN'}] is not of type 'object' [0]

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(finalpg[0])


for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# PRIYANKA PRIYANKA NOUN NNS compound XXXX True False
# RAIKWAR RAIKWAR NOUN NNS ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# CONTACT CONTACT PROPN NNP nmod XXXX True False
#                                                                 SPACE _SP       False False
# OBJECTIVE OBJECTIVE PROPN NNP appos XXXX True False
#
#
#  SPACE _SP
#  False False
# H.No:33 h.no:33 NOUN NN ROOT X.Xx:dd False False
# Shivasthali Shivasthali PROPN NNP compound Xxxxx True False
# Colony Colony PROPN NNP ROOT Xxxxx True False
# , , PUNCT , punct , False False
# Makronia Makronia PROPN NNP npadvmod Xxxxx True False
#       SPACE _SP     False False
# To to PART TO aux Xx True True
# Secure secure VERB VB ROOT Xxxxx True False
# a a DET DT det x True True
# position position NOUN NN dobj xxxx True False
# where where ADV WRB advmod xxxx True True
# I -PRON- PRON PRP nsubj X True True
# can can VERB MD aux xxx True True
# efficiently efficiently ADV RB advmod xxxx True False
# contribute contribute VERB VB relcl xxxx True False
# my -PRON- DET PRP$ poss xx True True
# skills skill NOUN NNS dobj xxxx True False
#
#
#  SPACE _SP
#  False False
# Sagar Sagar PROPN NNP appos Xxxxx True False
# . . PUNCT . punct . False False
#                                                                   SPACE _SP       False False
# and and CCONJ CC cc xxx True True
# abilities ability NOUN NNS conj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# growth growth NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# organization organization NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# build build VERB VB conj xxxx True False
# my -PRON- DET PRP$ poss xx True True
#
#
#  SPACE _SP
#  False False
# 7974849362 7974849362 NUM CD nummod dddd False False
#                                                           SPACE _SP       False False
# professional professional ADJ JJ amod xxxx True False
# career career NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# Priyankajma17@gmail.com Priyankajma17@gmail.com PROPN NNP ROOT Xxxxxdd@xxxx.xxx False False
#
#
#  SPACE _SP
#  False False
# EDUCATION EDUCATION PROPN NNP ROOT XXXX True False
#                                                             SPACE _SP       False False
# PROJECTS PROJECTS PROPN NNP ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# MNNIT MNNIT PROPN NNP compound XXXX True False
# ALLAHABAD ALLAHABAD PROPN NNP ROOT XXXX True False
# , , PUNCT , punct , False False
# PRAYAGRAJ PRAYAGRAJ PROPN NNP appos XXXX True False
#                           SPACE _SP       False False
# LIBRARY LIBRARY PROPN NNP compound XXXX True False
# MANAGEMENT MANAGEMENT PROPN NNP compound XXXX True False
# SYSTEM SYSTEM PROPN NNP appos XXXX True False
# | | PROPN NNP nmod | False False
# JAVA JAVA PROPN NNP appos XXXX True False
# | | PROPN NNP dep | False False
# MySQL MySQL PROPN NNP ROOT XxXXX True False
#
#
#  SPACE _SP
#  False False
# Master Master PROPN NNP appos Xxxxx True False
# of of ADP IN prep xx True True
# Computer Computer PROPN NNP compound Xxxxx True False
# Applications Applications PROPN NNPS pobj Xxxxx True False
#                 SPACE _SP       False False
# -2019 -2019 PROPN NNP ROOT -dddd False False
#
#
#                                         SPACE _SP
#      False False
# • • PROPN NNP compound • False False
# Students Students PROPN NNPS nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# admin admin PROPN NNP conj xxxx True False
# can can VERB MD aux xxx True True
# login login VERB VB ROOT xxxx True False
# with with ADP IN prep xxxx True True
# username username NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# password password NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# CPI CPI PROPN NNP ROOT XXX True False
# : : PUNCT : punct : False False
# 8.87 8.87 NUM CD appos d.dd False False
# ( ( PUNCT -LRB- ROOT ( False False
# Till till SCONJ IN intj Xxxx True False
# 5th 5th ADJ JJ amod dxx False False
# sem sem NOUN NN pobj xxx True False
# ) ) PUNCT -RRB- punct ) False False
#                   SPACE _SP       False False
# -2022 -2022 PUNCT : intj -dddd False False
#
#
#                                         SPACE _SP
#      False False
# • • PROPN NNP compound • False False
# Admin Admin PROPN NNP nsubj Xxxxx True False
# can can VERB MD aux xxx True True
# add add VERB VB ROOT xxx True False
# books book NOUN NNS dobj xxxx True False
# in in ADP IN prep xx True True
# database database NOUN NN pobj xxxx True False
# with with ADP IN prep xxxx True True
# unique unique ADJ JJ amod xxxx True False
# book book NOUN NN compound xxxx True False
# i -PRON- PRON PRP compound x True True
# d would VERB MD pobj x True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# Dr. Dr. PROPN NNP compound Xx. False False
# HARI HARI PROPN NNP compound XXXX True False
# SINGH SINGH PROPN NNP compound XXXX True False
# GOUR GOUR PROPN NNP nmod XXXX True False
# UNIVERSITY UNIVERSITY PROPN NNP ROOT XXXX True False
# | | PROPN NNP punct | False False
#               SPACE _SP       False False
# • • PART POS compound • False False
# Registered register VERB VBN amod Xxxxx True False
# students student NOUN NNS compound xxxx True False
# details detail NOUN NNS nsubj xxxx True False
# are be AUX VBP ROOT xxx True True
# available available ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# SAGAR SAGAR PROPN NNP ROOT XXXX True False
#                                                                     SPACE _SP       False False
# • • X XX compound • False False
# Admin Admin PROPN NNP nsubj Xxxxx True False
# can can VERB MD aux xxx True True
# check check VERB VB ROOT xxxx True False
# statistics statistic NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True True
# issued issue VERB VBN amod xxxx True False
# and and CCONJ CC cc xxx True True
# returned return VERB VBN conj xxxx True False
# book book NOUN NN npadvmod xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# Bachelor Bachelor PROPN NNP ROOT Xxxxx True False
# of of ADP IN prep xx True True
# Computer Computer PROPN NNP compound Xxxxx True False
# Applications Applications PROPN NNPS pobj Xxxxx True False
#             SPACE _SP       False False
# • • PROPN NNP compound • False False
# Calculate calculate VERB VBP ROOT Xxxxx True False
# fine fine NOUN NN advmod xxxx True False
# for for ADP IN prep xxx True True
# returning return VERB VBG pcomp xxxx True False
# the the DET DT det xxx True True
# book book NOUN NN dobj xxxx True False
# late late ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# CGPA:9.12 CGPA:9.12 PROPN NNP ROOT XXXX:d.dd False False
#                                                 SPACE _SP       False False
# -2018 -2018 X XX ROOT -dddd False False
#
#
#  SPACE _SP
#  False False
# D.M.A D.M.A PROPN NNP ROOT X.X.X False False
# SAGAR SAGAR PROPN NNP intj XXXX True False
#                                                         SPACE _SP       False False
# VIDEO VIDEO PROPN NNP compound XXXX True False
# CONTROLLING control VERB VBG ROOT XXXX True False
# BY by ADP IN prep XX True True
# HAND HAND PROPN NNP pobj XXXX True False
# GESTURE GESTURE PROPN NNP dobj XXXX True False
# | | PROPN NNP punct | False False
# PYTHON PYTHON PROPN NNP nmod XXXX True False
#
#
#  SPACE _SP
#  False False
# CLASS CLASS PROPN NNP nmod XXXX True False
# XII XII PROPN NNP ROOT XXX True False
# | | PROPN NNP ROOT | False False
# CBSE CBSE PROPN NNP ROOT XXXX True False
#                                               SPACE _SP       False False
# -2021 -2021 PROPN NNP ROOT -dddd False False
#
#
#  SPACE _SP
#  False False
# Percentage Percentage PROPN NNP ROOT Xxxxx True False
# : : PUNCT : punct : False False
# 71.4 71.4 NUM CD nummod dd.d False False
# % % NOUN NN appos % False False
#                                 SPACE _SP       False False
# -2015 -2015 PROPN NNP appos -dddd False False
# • • X XX compound • False False
# Libraries library NOUN NNS nsubj Xxxxx True False
# used use VERB VBN ROOT xxxx True True
# are be AUX VBP ccomp xxx True True
# OpenCV OpenCV PROPN NNP attr XxxxXX True False
# and and CCONJ CC cc xxx True True
# NumPy NumPy PROPN NNP conj XxxXx True False
# . . PUNCT . punct . False False
#
#
#                                         SPACE _SP
#      False False
# • • X ADD compound • False False
# Web web NOUN NN compound Xxx True False
# camera camera NOUN NN nsubj xxxx True False
# will will VERB MD aux xxxx True True
# detect detect VERB VB ROOT xxxx True False
# the the DET DT det xxx True True
# hand hand NOUN NN compound xxxx True False
# gesture gesture NOUN NN dobj xxxx True False
# & & CCONJ CC cc & False False
# respond respond PROPN NNP compound xxxx True False
# corresponding correspond VERB VBG conj xxxx True False
#
#
#  SPACE _SP
#  False False
# D.M.A D.M.A PROPN NNP intj X.X.X False False
# SAGAR SAGAR PROPN NNP ROOT XXXX True False
#                                                         SPACE _SP       False False
# to to ADP IN prep xx True True
# it -PRON- PRON PRP pobj xx True True
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# CLASS CLASS PROPN NNP ROOT XXXX True False
# X X PROPN NNP punct X True False
# | | PROPN NNP compound | False False
# CBSE CBSE PROPN NNP ROOT XXXX True False
#                                                   SPACE _SP       False False
# • • X ADD compound • False False
# Operation operation NOUN NN nsubj Xxxxx True False
# included include VERB VBD ROOT xxxx True False
# Pause Pause PROPN NNP dobj Xxxxx True False
# , , PUNCT , punct , False False
# play play NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# volume volume NOUN NN nsubj xxxx True False
# up- up- X XX conj xx- False False
# down down ADV RB advmod xxxx True True
# and and CCONJ CC cc xxx True True
# fast fast VERB VB advmod xxxx True False
# forward forward ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# CGPA CGPA PROPN NNP ROOT XXXX True False
# : : PUNCT : punct : False False
# 8.0 8.0 NUM CD appos d.d False False
#                                                 SPACE _SP       False False
# -2013 -2013 NOUN NNS intj -dddd False False
#
#
#                                         SPACE _SP
#      False False
# FIND find VERB VB ROOT XXXX True False
# VACCINATION vaccination NOUN NN compound XXXX True False
# SLOT SLOT PROPN NNP dobj XXXX True False
# | | PROPN NNP compound | False False
# PYTHON PYTHON PROPN NNP ROOT XXXX True False
# | | PROPN NNP ROOT | False False
# JSON JSON PROPN NNP ROOT XXXX True False
#
#
#                                         SPACE _SP
#      False False
# -2021 -2021 PROPN NNP ROOT -dddd False False
#
#
#                                         SPACE _SP
#      False False
# • • X XX ROOT • False False
# Using use VERB VBG ROOT Xxxxx True True
# the the DET DT det xxx True True
# Pycharm Pycharm PROPN NNP compound Xxxxx True False
# platform platform NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# Postman Postman PROPN NNP conj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#                                         SPACE _SP
#      False False
# • • X ADD nsubj • False False
# Can Can VERB MD aux Xxx True True
# check check VERB VB ROOT xxxx True False
# vaccinations vaccination NOUN NNS compound xxxx True False
# slots slot NOUN NNS dobj xxxx True False
# by by ADP IN prep xx True True
# PIN pin NOUN NN compound XXX True False
# code code NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# date date NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# AREA area NOUN NN ROOT XXXX True False
# OF of ADP IN prep XX True True
# INTEREST INTEREST PROPN NNP pobj XXXX True False
#                                               SPACE _SP       False False
# SKILLS SKILLS PROPN NNP ROOT XXXX True False
#
#
#      SPACE _SP
#      False False
#   NUM CD nummod  False False
#       SPACE _SP     False False
# Data datum NOUN NNS compound Xxxx True False
# structure structure NOUN NN ROOT xxxx True False
# and and CCONJ CC cc xxx True True
# Algorithm Algorithm PROPN NNP nmod Xxxxx True False
#       SPACE _SP     False False
# PROGRAMMING programming NOUN NN conj XXXX True False
# : : PUNCT : punct : False False
#
#
#                                         SPACE _SP
#      False False
# Familiar familiar ADJ JJ ROOT Xxxxx True False
# with with ADP IN prep xxxx True True
# : : PUNCT : punct : False False
# C C PROPN NNP nmod X True False
# / / SYM SYM punct / False False
# C++ C++ PROPN NNP pobj X++ False False
# , , PUNCT , punct , False False
# MySQL MySQL PROPN NNP compound XxXXX True False
#
#
#      SPACE _SP
#      False False
#   NOUN NN ROOT  False False
#       SPACE _SP     False False
# DBMS DBMS PROPN NNP compound XXXX True False
#                                                       SPACE _SP       False False
# Basics basic NOUN NNS ROOT Xxxxx True False
# : : PUNCT : punct : False False
#                   SPACE _SP       False False
# Java Java PROPN NNP appos Xxxx True False
# , , PUNCT , punct , False False
# Python Python PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# HTML HTML PROPN NNP conj XXXX True False
# , , PUNCT , punct , False False
# MongoDB MongoDB PROPN NNP conj XxxxxXX True False
#
#
#      SPACE _SP
#      False False
#   NUM CD ROOT  False False
#       SPACE _SP     False False
# Operating operating NOUN NN compound Xxxxx True False
# system system NOUN NN ROOT xxxx True False
#
#
#                                         SPACE _SP
#      False False
# TECHNICAL technical NOUN NN ROOT XXXX True False
# : : PUNCT : punct : False False
#
#
#                                         SPACE _SP
#      False False
# Familiar familiar ADJ JJ ROOT Xxxxx True False
# with with ADP IN prep xxxx True True
# : : PUNCT : punct : False False
# Anaconda Anaconda PROPN NNP ROOT Xxxxx True False
# , , PUNCT , punct , False False
# Postman Postman PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# Net net ADJ JJ amod Xxx True False
# beans bean NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# Visual Visual PROPN NNP compound Xxxxx True False
# Studio Studio PROPN NNP appos Xxxxx True False
# . . PUNCT . punct . False False
#
#
#                                         SPACE _SP
#      False False
# ACHIEVEMENTS ACHIEVEMENTS PROPN NNP ROOT XXXX True False
#
#
#   SPACE _SP
#   False False
# HOBBIES HOBBIES PROPN NNP conj XXXX True False
#                                                               SPACE _SP       False False
# ● ● PROPN NNP punct ● False False
# Certificate Certificate PROPN NNP appos Xxxxx True False
# of of ADP IN prep xx True True
# Completion Completion PROPN NNP pobj Xxxxx True False
# of of ADP IN prep xx True True
# “ " PUNCT `` punct “ False False
# Certified Certified PROPN NNP compound Xxxxx True False
# Network Network PROPN NNP compound Xxxxx True False
# Security Security PROPN NNP pobj Xxxxx True False
#
#
#      SPACE _SP
#      False False
#   NOUN NN ROOT  False False
#       SPACE _SP     False False
# To to PART TO aux Xx True True
# explore explore VERB VB ROOT xxxx True False
# new new ADJ JJ amod xxx True False
# technologies technology NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
#       SPACE _SP     False False
# Specialist(2020 Specialist(2020 PROPN NNP ROOT Xxxxx(dddd False False
# ) ) PUNCT -RRB- punct ) False False
# ” " PUNCT '' punct ” False False
# by(ICSI by(ICSI PROPN NNP punct xx(XXXX False False
# ) ) PUNCT -RRB- punct ) False False
#
#
#      SPACE _SP
#      False False
#   NUM CD ROOT  False False
#       SPACE _SP     False False
# To to PART TO aux Xx True True
# read read VERB VB ROOT xxxx True False
# chronicles chronicle NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True True
# freedom freedom NOUN NN pobj xxxx True False
#     SPACE _SP    False False
# ● ● PUNCT NFP punct ● False False
# Member Member PROPN NNP dep Xxxxx True False
# of of ADP IN prep xx True True
# Volleyball Volleyball PROPN NNP compound Xxxxx True False
# team(2019 team(2019 NOUN NN pobj xxxx(dddd False False
# ) ) PUNCT -RRB- punct ) False False
# at at ADP IN prep xx True True
# MNNIT MNNIT PROPN NNP compound XXXX True False
# Allahabad Allahabad PROPN NNP nmod Xxxxx True False
#
#
#          SPACE _SP
#      False False
# fighters fighter NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
#                                             SPACE _SP       False False
# ● ● NUM CD punct ● False False
# Got get VERB VBD ROOT Xxx True False
# a a DET DT det x True True
# gold gold NOUN NN compound xxxx True False
# medal medal NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# kabaddi kabaddi PROPN NNP pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 2019 2019 NUM CD appos dddd False False
# ) ) PUNCT -RRB- punct ) False False
# at at ADP IN prep xx True True
# MNNIT MNNIT PROPN NNP compound XXXX True False
# Allahabad Allahabad PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#      SPACE _SP
#      False False
#   NUM CD ROOT  False False
#       SPACE _SP     False False
# Drawing Drawing PROPN NNP nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Sketching Sketching PROPN NNP conj Xxxxx True False
#                     SPACE _SP       False False
# ● ● PUNCT NFP punct ● False False
# Worked work VERB VBN ROOT Xxxxx True False
# as as SCONJ IN prep xx True True
# Class Class PROPN NNP compound Xxxxx True False
# Representative Representative PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True True
# BCA BCA PROPN NNP pobj XXX True False
# . . PUNCT . punct . False False
#
#
#                                         SPACE _SP
#      False False
# ● ● NUM CD punct ● False False
# Got got VERB VB ROOT Xxx True False
# second second ADJ JJ amod xxxx True False
# position position NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# National National PROPN NNP compound Xxxxx True False
# Science Science PROPN NNP nmod Xxxxx True False
# Day(2017 Day(2017 PROPN NNP dep Xxx(dddd False False
# ) ) PUNCT -RRB- punct ) False False
# Event event NOUN NN pobj Xxxxx True False
