# %% [markdown]
# <a href="https://colab.research.google.com/github/pararthdave/ResumeParser/blob/Priyanka/hobbies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 6.2 MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61102 sha256=fa69929bf2125a04f3bf9bd79adf8b36e6d419ba9a2daa68bc03e8ffbc0a5cbe
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
#   cuda-nsight-compute-10-1 cuda-nsight-compute-11-0 cuda-nsight-compute-11-1
#   cuda-nsight-systems-10-1 cuda-nsight-systems-11-0 cuda-nsight-systems-11-1
#   cuda-nvcc-10-0 cuda-nvcc-10-1 cuda-nvcc-11-0 cuda-nvdisasm-10-0
#   cuda-nvdisasm-10-1 cuda-nvdisasm-11-0 cuda-nvml-dev-10-0 cuda-nvml-dev-10-1
#   cuda-nvml-dev-11-0 cuda-nvprof-10-0 cuda-nvprof-10-1 cuda-nvprof-11-0
#   cuda-nvprune-10-0 cuda-nvprune-10-1 cuda-nvprune-11-0 cuda-nvtx-10-0
#   cuda-nvtx-10-1 cuda-nvtx-11-0 cuda-nvvp-10-0 cuda-nvvp-10-1 cuda-nvvp-11-0
#   cuda-nvvp-11-1 cuda-samples-10-0 cuda-samples-10-1 cuda-samples-11-0
#   cuda-samples-11-1 cuda-sanitizer-11-0 cuda-sanitizer-api-10-1
#   cuda-toolkit-10-0 cuda-toolkit-10-1 cuda-toolkit-11-0 cuda-toolkit-11-1
#   cuda-tools-10-0 cuda-tools-10-1 cuda-tools-11-0 cuda-tools-11-1
#   cuda-visual-tools-10-0 cuda-visual-tools-10-1 cuda-visual-tools-11-0
#   cuda-visual-tools-11-1 default-jre dkms freeglut3 freeglut3-dev
#   keyboard-configuration libargon2-0 libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfontenc1 libidn11 libip4tc0 libjansson4
#   libnvidia-cfg1-510 libnvidia-common-460 libnvidia-common-510
#   libnvidia-extra-510 libnvidia-fbc1-510 libnvidia-gl-510 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2
#   libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0 libxtst6
#   nsight-compute-2020.2.1 nsight-compute-2022.1.0 nsight-systems-2020.3.2
#   nsight-systems-2020.3.4 nsight-systems-2021.5.2 nvidia-dkms-510
#   nvidia-kernel-common-510 nvidia-kernel-source-510 nvidia-modprobe
#   nvidia-settings openjdk-11-jre policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils
#   xserver-common xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-510
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libpoppler-cpp0v5
# The following NEW packages will be installed:
#   libpoppler-cpp-dev libpoppler-cpp0v5
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 36.7 kB of archives.
# After this operation, 188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp0v5 amd64 0.62.0-2ubuntu2.12 [28.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp-dev amd64 0.62.0-2ubuntu2.12 [8,676 B]
# Fetched 36.7 kB in 0s (110 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpoppler-cpp0v5:amd64.
# (Reading database ... 155113 files and directories currently installed.)
# Preparing to unpack .../libpoppler-cpp0v5_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Selecting previously unselected package libpoppler-cpp-dev:amd64.
# Preparing to unpack .../libpoppler-cpp-dev_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !pip install pdftotext
# Out:
# Collecting pdftotext
#   Downloading pdftotext-2.2.2.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 23.1 MB/s
# Building wheels for collected packages: pdftotext
#   Building wheel for pdftotext (setup.py) ... done
#   Created wheel for pdftotext: filename=pdftotext-2.2.2-cp37-cp37m-linux_x86_64.whl size=54910 sha256=f38d7708d3aed63bc5c9477078893b693b11b9f7bf1cc9c3182d712745e24ec0
#   Stored in directory: /root/.cache/pip/wheels/98/19/8e/e8648026db8b7ef3324ad9afa1f7c9109a7e7509846f693ed9
# Successfully built pdftotext
# Installing collected packages: pdftotext
# Successfully installed pdftotext-2.2.2

# %%
# !cp -rv /content/drive/MyDrive/dataset .
# Out:
# '/content/drive/MyDrive/dataset' -> './dataset'
# '/content/drive/MyDrive/dataset/pararthdave_Resume.pdf' -> './dataset/pararthdave_Resume.pdf'
# '/content/drive/MyDrive/dataset/Mandar bhoir Resume (1)_compressed.pdf' -> './dataset/Mandar bhoir Resume (1)_compressed.pdf'
# '/content/drive/MyDrive/dataset/YOGAPRIYA H_RESUME.pdf' -> './dataset/YOGAPRIYA H_RESUME.pdf'
# '/content/drive/MyDrive/dataset/Harika Sonnathi Resume 2022 2.pdf' -> './dataset/Harika Sonnathi Resume 2022 2.pdf'
# '/content/drive/MyDrive/dataset/Priyanka_RaikwarRESUME.pdf' -> './dataset/Priyanka_RaikwarRESUME.pdf'
# '/content/drive/MyDrive/dataset/priyanka_resume(8).pdf' -> './dataset/priyanka_resume(8).pdf'
# '/content/drive/MyDrive/dataset/KetanPawarResume.pdf' -> './dataset/KetanPawarResume.pdf'
# '/content/drive/MyDrive/dataset/ravisatvik.192_Resume.pdf' -> './dataset/ravisatvik.192_Resume.pdf'

# %%
import PyPDF2
import spacy
from spacy.matcher import Matcher
import pdftotext
import pandas as pd
import os

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 28.0 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
path='/content/dataset' #file path for corpus
files = [os.path.join (path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
pdfs = []
for i in files:
    pdfs.append(i)

merger = PyPDF2.PdfFileMerger(strict=False)

for pdf in pdfs:
    merger.append(pdf)

merger.write("final.pdf")
# Out:
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2379 for key /h.6dzabhgz4wnn [generic.py:588]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23d7 for key /h.xzo9n6yunfn [generic.py:588]

# %%
with open("final.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
finalpg=[]
for page in pdf:
    pg=page.strip()
    finalpg.append(pg)
print(finalpg[2])
# Out:
# 8/4/2021                                                                           202018016_Resume
#                                                           Pararth Dave
#                                                           Dhirubhai Ambani Institute of Information and Communication Technology
#                                                           Email: 202018016@daiict.ac.in                       DOB: May 26, 2000
#                                                           Address: 1/45, Opp. BSNL Telephone Exchange, Housing Board, Dungarpur (Raj)
#  EDUCATION
#  Degree                                                                        University/Institute                         Year CPI/Aggregate
#  M.Sc. | DS                                   Dhirubhai Ambani Institute of Information and Communication Technology 2022            8.61 CPI
#  B.Sc. | CA & IT                              Natubhai V. Patel College of Pure and Applied Sciences                       2020     8.85 CGPA
#  Higher Secondary | Class XII Kendriya Vidyalaya Dungarpur (CBSE)                                                          2017       83.6%
#  Secondary | Class X                          Kendriya Vidyalaya Dungarpur (CBSE)                                          2015     9.8 CGPA
#  SKILLS
#                                                          NLP, IR, ML, FrontEnd, Django, Bootstrap, HTML, CSS, SAS Certified Specialist: Machine
#                                                          Learning Using SAS Viya 3.5, SAS Certified Data Integration Developer for SAS 9, SAS
#  Expertise Area/Area(s) of Interest
#                                                          Certified Specialist: Base Programming Using SAS 9.4
#  Programming Language(s)                                 Python, R, SAS, SQL, Django, Bootstrap, CSS, HTML5, Java (Advanced)
#                                                          Netbeans, Oracle Apex, Adobe Illustrator, Adobe Photoshop, Canva, Jupyter Notebook,
#                                                          R Studio, SAS Enterprise Guide, VS Code, Pycharm IDE, SAS Viya, and other SAS
#  Tools and Technologies
#                                                          platforms
#  Technical Electives                                     Information Retrieval, Natural Language Processing
#  PROFESSIONAL EXPERIENCE/INTERNSHIPS
#  IRLAB-DAIICT                             Legal Document Summarization project in collaboration with IIT                    July-2021 - Ongoing
#                                           Kharagpur, worked on various architectures and implemented a UI to
#                                                                                                                                  Team Size: - 02
#                                           tweak the parameters and fetch relevant documents and summarize them
#                                           using NLP and Human Computer Interaction.
#                                           Guide: Dr. Prasenjit Majumder
#  IRLAB-DAIICT                             3 in 1 web-app developed under the umbrella of summer internship. Had             May-2021 - Ongoing
#                                           various modules that included Sentiment Analysis of YouTube Videos,
#                                                                                                                                  Team Size - 07
#                                           Stock Market Prediction, and Power Utilization Prediction. Various
#                                           concepts of Data Science and Front-end Design were used and learnt.
#                                           Guide: Dr. Prasenjit Majumder
#  Aadox                                    One-Month Content Writing Internship based on various technological             May 2019 - June 2019
#                                           aspects, the content was SEO-based and a freelance internship.
#                                                                                                                                  Team Size - 06
#                                           Guide: Ms. Madhu Singh, Team Leader, Aadox, Lucknow
# https://daiict-placement-cell.github.io/ResumeMaker/resume_daiict_regular.html                                                                 1/4

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(finalpg[0])


for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Projects project NOUN NNS nmod Xxxxx True False
#
#
#    SPACE _SP
#    False False
# RAVI ravi NOUN NN compound XXXX True False
# SATVIK SATVIK PROPN NNP compound XXXX True False
#                                                                                           SPACE _SP       False False
# Prediction Prediction PROPN NNP nsubj Xxxxx True False
# of of ADP IN prep xx True True
# COVID-19 covid-19 ADJ JJ compound XXXX-dd False False
# Infection Infection PROPN NNP pobj Xxxxx True False
# Using use VERB VBG acl Xxxxx True True
# Epidemiology epidemiology NOUN NN dobj Xxxxx True False
#
#
#    SPACE _SP
#    False False
# GORTHI GORTHI PROPN NNP ROOT XXXX True False
#
#
#                                                            SPACE _SP
#      False False
# Dataset dataset NOUN NN ROOT Xxxxx True False
#
#
#                                                                SPACE _SP
#      False False
# We -PRON- PRON PRP nsubj Xx True True
# predicted predict VERB VBD ROOT xxxx True False
# and and CCONJ CC cc xxx True True
# forecasted forecast VERB VBD conj xxxx True False
# the the DET DT det xxx True True
# COVID-19 covid-19 ADJ JJ nummod XXXX-dd False False
# outbreak outbreak NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
#
#
#                                                                SPACE _SP
#      False False
# World World PROPN NNP pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# India India PROPN NNP conj Xxxxx True False
# using use VERB VBG advcl xxxx True True
# a a DET DT det x True True
# machine machine NOUN NN compound xxxx True False
# learning learning NOUN NN compound xxxx True False
# approach approach NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# aim aim NOUN NN intj xxx True False
# of of ADP IN prep xx True True
#
#
#                                                                SPACE _SP
#      False False
# the the DET DT det xxx True True
# project project NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# to to PART TO aux xx True True
# provide provide VERB VB xcomp xxxx True False
# data data NOUN NN compound xxxx True False
# analysis analysis NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# covid-19 covid-19 PROPN NNP pobj xxxx-dd False False
# using use VERB VBG advcl xxxx True True
# ML ML PROPN NNP nmod XX True False
#
#
#                        SPACE _SP
#      False False
# Data Data PROPN NNP compound Xxxx True False
# Scientist Scientist PROPN NNP appos Xxxxx True False
#                                                     SPACE _SP       False False
# models model NOUN NNS dobj xxxx True False
# SVM SVM PROPN NNP appos XXX True False
# and and CCONJ CC cc xxx True True
# polynomial polynomial ADJ JJ amod xxxx True False
# regression regression NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# SVM SVM PROPN NNP compound XXX True False
# model model NOUN NN nsubj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# performed perform VERB VBD ROOT xxxx True False
# better better ADV RBR advmod xxxx True False
# on on ADP IN prep xx True True
# India India PROPN NNP compound Xxxxx True False
# data datum NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# whereas whereas SCONJ IN mark xxxx True True
# the the DET DT det xxx True True
# polynomial polynomial NOUN NN amod xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# regression regression NOUN NN compound xxxx True False
# model model NOUN NN nsubj xxxx True False
# performs perform VERB VBZ advcl xxxx True False
# better better ADV RB advmod xxxx True False
# when when ADV WRB advmod xxxx True True
# considering consider VERB VBG advcl xxxx True False
# the the DET DT det xxx True True
# world world NOUN NN dobj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# data datum NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# We -PRON- PRON PRP nsubj Xx True True
# evaluated evaluate VERB VBD ROOT xxxx True False
# the the DET DT det xxx True True
# models model NOUN NNS dobj xxxx True False
# based base VERB VBN acl xxxx True False
# on on ADP IN prep xx True True
# Mean Mean PROPN NNP compound Xxxx True False
# Average Average PROPN NNP compound Xxxxx True False
# Error Error PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#    SPACE _SP
#    False False
# Technical Technical PROPN NNP compound Xxxxx True False
# Skills Skills PROPN NNP ROOT Xxxxx True False
#
#
#                                                            SPACE _SP
#      False False
# Detection Detection PROPN NNP appos Xxxxx True False
# and and CCONJ CC cc xxx True True
# Resolution Resolution PROPN NNP conj Xxxxx True False
# of of ADP IN prep xx True True
# Rumors Rumors PROPN NNPS pobj Xxxxx True False
# in in ADP IN prep xx True True
# Social Social PROPN NNP compound Xxxxx True False
# Media Media PROPN NNP pobj Xxxxx True False
# : : PUNCT : punct : False False
#
#
#      SPACE _SP
#      False False
# ● ● PUNCT NFP punct ● False False
#       SPACE _SP     False False
# SAS SAS PROPN NNP compound XXX True False
# Certified Certified PROPN NNP compound Xxxxx True False
# Specialist Specialist PROPN NNP ROOT Xxxxx True False
# : : PUNCT : punct : False False
# Base Base PROPN NNP compound Xxxx True False
# Programming Programming PROPN NNP ROOT Xxxxx True False
# Using Using PROPN NNP acl Xxxxx True True
#     SPACE _SP    False False
# A a DET DT det X True True
# Survey Survey PROPN NNP dobj Xxxxx True False
#
#
#          SPACE _SP
#      False False
# SAS SAS PROPN NNP ROOT XXX True False
# 9.4 9.4 NUM CD nummod d.d False False
#
#
#                                                                SPACE _SP
#      False False
# - - PUNCT : punct - False False
# This this DET DT det Xxxx True True
# project project NOUN NN nsubj xxxx True False
# addresses address VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True True
# challenge challenge NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# rumor rumor NOUN NN amod xxxx True False
# stance stance NOUN NN pobj xxxx True False
#
#
#      SPACE _SP
#      False False
# ● ● PUNCT NFP punct ● False False
#       SPACE _SP     False False
# Languages language NOUN NNS ROOT Xxxxx True False
# : : PUNCT : punct : False False
# Python Python PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# R R PROPN NNP compound X True False
#                                                                     SPACE _SP       False False
# classification classification NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# which which DET WDT nsubj xxxx True True
# involves involve VERB VBZ relcl xxxx True False
# identifying identify VERB VBG xcomp xxxx True False
# the the DET DT det xxx True True
# stances stance NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True True
# users user NOUN NNS pobj xxxx True False
#
#
#      SPACE _SP
#      False False
# ● ● PUNCT NFP punct ● False False
#       SPACE _SP     False False
# Packages package NOUN NNS ROOT Xxxxx True False
# : : PUNCT : punct : False False
# skLearn skLearn PROPN NNP appos xxXxxxx True False
# , , PUNCT , punct , False False
# Keras Keras PROPN NNPS conj Xxxxx True False
# , , PUNCT , punct , False False
# spaCY spacy X ADD appos xxxXX True False
#                                               SPACE _SP       False False
# towards towards ADP IN prep xxxx True True
# the the DET DT det xxx True True
# veracity veracity NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# rumor rumor NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#      SPACE _SP
#      False False
# ● ● PUNCT NFP punct ● False False
#       SPACE _SP     False False
# Platforms platform NOUN NNS ROOT Xxxxx True False
# : : PUNCT : punct : False False
# Anaconda Anaconda PROPN NNP ROOT Xxxxx True False
# , , PUNCT , punct , False False
# Jupyter Jupyter PROPN NNP compound Xxxxx True False
# Notebook Notebook PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# PyCharm PyCharm PROPN NNP ROOT XxXxxxx True False
#                 SPACE _SP       False False
# - - PUNCT HYPH punct - False False
# We -PRON- PRON PRP nsubj Xx True True
# implemented implement VERB VBD ccomp xxxx True False
# an an DET DT det xx True True
# LSTM LSTM PROPN NNP npadvmod XXXX True False
# - - PUNCT HYPH punct - False False
# based base VERB VBN amod xxxx True False
# sequential sequential ADJ JJ amod xxxx True False
# model model NOUN NN dobj xxxx True False
# which which DET WDT nsubj xxxx True True
# takes take VERB VBZ relcl xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# sequences sequence NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# source source NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# their -PRON- DET PRP$ poss xxxx True True
# corresponding corresponding ADJ JJ amod xxxx True False
# reply reply NOUN NN compound xxxx True False
# tweets tweet NOUN NNS conj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# as as SCONJ IN prep xx True True
# input input NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# gives give VERB VBZ conj xxxx True False
# stances stance NOUN NNS dobj xxxx True False
# for for ADP IN dative xxx True True
# all all DET PDT predet xxx True True
# the the DET DT det xxx True True
# underlying underlie VERB VBG amod xxxx True False
# tweets tweet NOUN NNS pobj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# - - PUNCT : punct - False False
# Since since SCONJ IN mark Xxxxx True True
# this this DET DT nsubj xxxx True True
# is be AUX VBZ advcl xx True True
# a a DET DT det x True True
# classification classification NOUN NN compound xxxx True False
# problem problem NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# we -PRON- PRON PRP nsubj xx True True
# used use VERB VBD ROOT xxxx True True
# accuracy accuracy NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# F1 f1 NOUN NN conj Xd False False
#
#
#    SPACE _SP
#    False False
# Contact contact NOUN NN compound Xxxxx True False
#                                                                                                           SPACE _SP       False False
# macro macro NOUN NN nsubj xxxx True False
# averaged average VERB VBD conj xxxx True False
# score score NOUN NN dobj xxxx True False
# to to PART TO aux xx True True
# evaluate evaluate VERB VB xcomp xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# model model NOUN NN nsubj xxxx True False
# performed perform VERB VBD ROOT xxxx True False
# with with ADP IN prep xxxx True True
#
#
#                                                                SPACE _SP
#      False False
# an an DET DT det xx True True
# accuracy accuracy NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# 0.43 0.43 NUM CD pobj d.dd False False
# and and CCONJ CC cc xxx True True
# F1 F1 PROPN NNP compound Xd False False
# macro macro ADJ JJ compound xxxx True False
# score score NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# 0.25 0.25 NUM CD pobj d.dd False False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# +91 +91 NUM CD ROOT +dd False False
# 7013057375 7013057375 NUM CD nummod dddd False False
#
#
#                                                            SPACE _SP
#      False False
# Hate Hate PROPN NNP compound Xxxx True False
# Speech Speech PROPN NNP ROOT Xxxxx True False
# and and CCONJ CC cc xxx True True
# Fake Fake PROPN NNP amod Xxxx True False
# News News PROPN NNP compound Xxxx True False
# Detection Detection PROPN NNP conj Xxxxx True False
#
#
#  SPACE _SP
#  False False
# ravisatvik.192@gmail.com ravisatvik.192@gmail.com PROPN NNP ROOT xxxx.ddd@xxxx.xxx False False
#
#
#  SPACE _SP
#  False False
# linkedin.com/ravi-gorthi linkedin.com/ravi-gorthi PROPN NNP ROOT xxxx.xxx/xxxx-xxxx False False
#                                                                             SPACE _SP       False False
# - - PUNCT , punct - False False
# Over over ADP IN intj Xxxx True True
# the the DET DT det xxx True True
# past past ADJ JJ amod xxxx True False
# years year NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# interest interest NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# online online ADJ JJ amod xxxx True False
# hate hate NOUN NN compound xxxx True False
# speech speech NOUN NN compound xxxx True False
# detection detection NOUN NN pobj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# and and CCONJ CC cc xxx True True
# , , PUNCT , punct , False False
# particularly particularly ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# automation automation NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# this this DET DT det xxxx True True
# task task NOUN NN pobj xxxx True False
# has have AUX VBZ aux xxx True True
# continuously continuously ADV RB advmod xxxx True False
#
#
#  SPACE _SP
#  False False
# github.com/rgorthi github.com/rgorthi PROPN NNP compound xxxx.xxx/xxxx False False
#                                                                                         SPACE _SP       False False
# grown grow VERB VBN ROOT xxxx True False
# , , PUNCT , punct , False False
# along along ADP IN prep xxxx True True
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# societal societal ADJ JJ amod xxxx True False
# impact impact NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# incident incident NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# This this DET DT det Xxxx True True
#
#
#                                                                SPACE _SP
#      False False
# project project NOUN NN nsubj xxxx True False
# describes describe VERB VBZ ROOT xxxx True False
# a a DET DT det x True True
# hate hate NOUN NN compound xxxx True False
# speech speech NOUN NN compound xxxx True False
# classification classification NOUN NN compound xxxx True False
# model model NOUN NN dobj xxxx True False
# based base VERB VBN acl xxxx True False
# on on ADP IN prep xx True True
#
#
#                                                                SPACE _SP
#      False False
# Distil Distil PROPN NNP compound Xxxxx True False
# - - PUNCT HYPH punct - False False
# BERT BERT PROPN NNP pobj XXXX True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# Academic Academic PROPN NNP advmod Xxxxx True False
#                                                                                                             SPACE _SP       False False
# - - PUNCT : punct - False False
# This this DET DT det Xxxx True True
# project project NOUN NN nsubj xxxx True False
# also also ADV RB advmod xxxx True True
# describes describe VERB VBZ ROOT xxxx True False
# a a DET DT det x True True
# fake fake ADJ JJ amod xxxx True False
# news news NOUN NN compound xxxx True False
# classification classification NOUN NN compound xxxx True False
# model model NOUN NN dobj xxxx True False
#
#
#                                                                SPACE _SP
#      False False
# based base VERB VBN acl xxxx True False
# on on ADP IN prep xx True True
# GloVe GloVe PROPN NNP amod XxxXx True False
# embeddings embedding NOUN NNS pobj xxxx True False
# for for ADP IN prep xxx True True
# feature feature NOUN NN compound xxxx True False
# extraction extraction NOUN NN pobj xxxx True False
# followed follow VERB VBN acl xxxx True False
# by by ADP IN agent xx True True
#
#
#  SPACE _SP
#  False False
# Qualifications Qualifications PROPN NNP pobj Xxxxx True False
#                                                                                                 SPACE _SP       False False
# training train VERB VBG advcl xxxx True False
# an an DET DT det xx True True
# LSTM LSTM PROPN NNP compound XXXX True False
# model model NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#
#
#                                                                SPACE _SP
#      False False
# -The -The PUNCT . ROOT -Xxx False False
# LSTM LSTM PROPN NNP compound XXXX True False
# model model NOUN NN ROOT xxxx True False
# performed perform VERB VBN acl xxxx True False
# with with ADP IN prep xxxx True True
# a a DET DT det x True True
# weighted weighted ADJ JJ amod xxxx True False
# F1 F1 PROPN NNP compound Xd False False
# score score NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# 0.90 0.90 NUM CD pobj d.dd False False
# . . PUNCT . punct . False False
#
#
#                                                                SPACE _SP
#      False False
# The the DET DT det Xxx True True
# distil- distil- ADJ JJ compound xxxx- False False
# BERT BERT PROPN NNP compound XXXX True False
# model model NOUN NN ROOT xxxx True False
# performed perform VERB VBN acl xxxx True False
# with with ADP IN prep xxxx True True
# an an DET DT det xx True True
# accuracy accuracy NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# 0.84 0.84 NUM CD pobj d.dd False False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# MASTER master NOUN NN ROOT XXXX True False
# OF of ADP IN prep XX True True
# SCIENCE SCIENCE PROPN NNP pobj XXXX True False
# ( ( PUNCT -LRB- punct ( False False
# Data Data PROPN NNP compound Xxxx True False
# Science Science PROPN NNP ROOT Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE _SP
#  False False
# D.A.I.I.C.T D.A.I.I.C.T NOUN NNS ROOT X.X.X.X.X.X False False
# , , PUNCT , punct , False False
# 2022 2022 NUM CD nummod dddd False False
#
#
#                                                           SPACE _SP
#      False False
# Work work NOUN NN compound Xxxx True False
# Experience experience NOUN NN appos Xxxxx True False
#
#
#  SPACE _SP
#  False False
# BACHELOR BACHELOR NOUN NNS appos XXXX True False
# OF of ADP IN prep XX True True
# TECHNOLOGY(Computer TECHNOLOGY(Computer PROPN NNP compound XXXX(Xxxxx False False
# Science Science PROPN NNP pobj Xxxxx True False
#
#
#  SPACE _SP
#  False False
# and and CCONJ CC cc xxx True True
# Engineering Engineering PROPN NNP conj Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
#                                                                                     SPACE _SP       False False
# ModulusPI ModulusPI PROPN NNP compound XxxxxXX True False
# IT IT PROPN NNP compound XX True True
# Solutions Solutions PROPN NNPS conj Xxxxx True False
# , , PUNCT , punct , False False
# Hyderabad Hyderabad PROPN NNP npadvmod Xxxxx True False
#
#
#  SPACE _SP
#  False False
# SRM SRM PROPN NNP compound XXX True False
# University University PROPN NNP ROOT Xxxxx True False
# , , PUNCT , punct , False False
# 2018 2018 NUM CD npadvmod dddd False False
#                                                                             SPACE _SP       False False
# 1 1 NUM CD nummod d False False
# year year NOUN NN npadvmod xxxx True False
# as as SCONJ IN mark xx True True
# AR AR PROPN NNP nmod XX True False
# / / SYM SYM punct / False False
# VR VR PROPN NNP compound XX True False
# Developer developer NOUN NN nsubj Xxxxx True False
#
#
#                                                               SPACE _SP
#      False False
# Worked work VERB VBN ROOT Xxxxx True False
# on on ADP IN prep xx True True
# VR VR PROPN NNP compound XX True False
# projects project NOUN NNS pobj xxxx True False
# for for ADP IN prep xxx True True
# HTC HTC PROPN NNP compound XXX True False
# Vive Vive PROPN NNP pobj Xxxx True False
# , , PUNCT , punct , False False
# Oculus Oculus PROPN NNP compound Xxxxx True False
# Rift Rift PROPN NNP conj Xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# Windows Windows PROPN NNP conj Xxxxx True False
#
#
#                                                               SPACE _SP
#      False False
# Mixed Mixed PROPN NNP compound Xxxxx True False
# Reality Reality PROPN NNP ROOT Xxxxx True False
# using use VERB VBG acl xxxx True True
# Unreal Unreal PROPN NNP compound Xxxxx True False
# Engine Engine PROPN NNP dobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#                                                                SPACE _SP
#      False False
# - - PUNCT : punct - False False
# Developed develop VERB VBN ROOT Xxxxx True False
# a a DET DT det x True True
# VR VR PROPN NNP compound XX True False
# Application application NOUN NN dobj Xxxxx True False
# for for ADP IN prep xxx True True
# Patient- Patient- PROPN NNP nummod Xxxxx- False False
# Doctor Doctor PROPN NNP compound Xxxxx True False
# Interaction Interaction PROPN NNP pobj Xxxxx True False
#
#
#  SPACE _SP
#  False False
# Skills Skills PROPN NNP npadvmod Xxxxx True False
#                                                                                                                 SPACE _SP       False False
# - - PUNCT HYPH punct - False False
# Built build VERB VBN ROOT Xxxxx True False
# and and CCONJ CC cc xxx True True
# developed develop VERB VBD conj xxxx True False
# a a DET DT det x True True
# VR VR PROPN NNP nmod XX True False
# Real Real PROPN NNP compound Xxxx True False
# Estate Estate PROPN NNP compound Xxxxx True False
# Concept Concept PROPN NNP compound Xxxxx True False
# Visualization Visualization PROPN NNP nmod Xxxxx True False
#
#
#                                                                SPACE _SP
#      False False
# Tool Tool PROPN NNP nmod Xxxx True False
#
#
#      SPACE _SP
#      False False
# DATA DATA PROPN NNP compound XXXX True False
# ANALYSIS ANALYSIS PROPN NNP compound XXXX True False
#                                                                                           SPACE _SP       False False
# - - PUNCT HYPH punct - False False
# Worked work VERB VBD dobj Xxxxx True False
# on on ADP IN prep xx True True
# a a DET DT det x True True
# VR VR PROPN NNP compound XX True False
# Tool Tool PROPN NNP pobj Xxxx True False
# For for ADP IN prep Xxx True True
# Training training NOUN NN nmod Xxxxx True False
# and and CCONJ CC cc xxx True True
# Evaluation Evaluation PROPN NNP conj Xxxxx True False
# Module Module PROPN NNP pobj Xxxxx True False
# for for ADP IN prep xxx True True
#
#
#                                                                SPACE _SP
#      False False
# warehouse warehouse NOUN NN compound xxxx True False
# safety safety NOUN NN pobj xxxx True False
#
#
#      SPACE _SP
#      False False
# MODEL MODEL PROPN NNP compound XXXX True False
# BUILDING BUILDING PROPN NNP ROOT XXXX True False
#
#
#                                                                SPACE _SP
#      False False
# - - PUNCT HYPH punct - False False
# Developed develop VERB VBN amod Xxxxx True False
# several several ADJ JJ amod xxxx True True
# in in ADP IN nmod xx True True
# - - PUNCT HYPH punct - False False
# house house NOUN NN pobj xxxx True False
# projects project NOUN NNS ROOT xxxx True False
# for for ADP IN prep xxx True True
# POC POC PROPN NNP pobj XXX True False
#
#
#      SPACE _SP
#      False False
# MACHINE MACHINE PROPN NNP compound XXXX True False
# LEARNING learning NOUN NN ROOT XXXX True False
#
#
#      SPACE _SP
#      False False
# DEEP DEEP PROPN NNP amod XXXX True False
# LEARNING LEARNING PROPN NNP ROOT XXXX True False
#                                                                                   SPACE _SP       False False
# AutoVRse AutoVRse NOUN NNS ROOT XxxxXXxx True False
# , , PUNCT , punct , False False
# Bangalore Bangalore PROPN NNP compound Xxxxx True False
#                                   SPACE _SP       False False
# 6 6 NUM CD nummod d False False
# Months Months PROPN NNPS appos Xxxxx True False
# of of ADP IN prep xx True True
# Internship Internship PROPN NNP nmod Xxxxx True False
#
#
#      SPACE _SP
#      False False
# NATURAL NATURAL PROPN NNP compound XXXX True False
# LANGUAGE LANGUAGE PROPN NNP compound XXXX True False
# PROCESSING processing NOUN NN pobj XXXX True False
#
#
#                                                               SPACE _SP
#      False False
# - - PUNCT : punct - False False
# Built build VERB VBN ROOT Xxxxx True False
# a a DET DT det x True True
# VR VR PROPN NNP compound XX True False
# Experience experience NOUN NN dobj Xxxxx True False
# of of ADP IN prep xx True True
# Service Service PROPN NNP compound Xxxxx True False
# Centers Centers PROPN NNPS pobj Xxxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# Future Future PROPN NNP pobj Xxxxx True False
# for for ADP IN prep xxx True True
#
#
#      SPACE _SP
#      False False
# MODEL model NOUN NN compound XXXX True False
# DEPLOYMENT deployment NOUN NN pobj XXXX True False
# IN in ADP IN prep XX True True
# CLOUD CLOUD PROPN NNP nmod XXXX True False
#                                                                 SPACE _SP       False False
# Greaves Greaves PROPN NNP compound Xxxxx True False
# Cotton Cotton PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# Chennai Chennai PROPN NNP appos Xxxxx True False
# . . PUNCT . punct . False False
#
#
#                                                               SPACE _SP
#      False False
# - - PUNCT : punct - False False
# Built build VERB VBN ROOT Xxxxx True False
# a a DET DT det x True True
# VR VR PROPN NNP compound XX True False
# model model NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# Bus Bus PROPN NNP pobj Xxx True False
# , , PUNCT , punct , False False
# to to PART TO aux xx True True
# view view VERB VB advcl xxxx True False
# under under ADP IN prep xxxx True True
# custom custom NOUN NN compound xxxx True False
# exterior exterior PROPN NNP nmod xxxx True False
#
#
#      SPACE _SP
#      False False
# VERSION version NOUN NN compound XXXX True False
# CONTROL control NOUN NN nmod XXXX True False
# AND and CCONJ CC cc XXX True True
# REPORT report ADJ JJ compound XXXX True False
# GENERATION GENERATION PROPN NNP conj XXXX True False
#                                         SPACE _SP       False False
# settings setting NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# preset preset ADJ JJ amod xxxx True False
# interiors interior NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# lighting light VERB VBG conj xxxx True False
# for for ADP IN prep xxx True True
# a a DET DT det x True True
# major major ADJ JJ amod xxxx True False
# automobile automobile NOUN NN compound xxxx True False
# firm firm NOUN NN pobj xxxx True False
#
#
#                                                               SPACE _SP
#      False False
# in in ADP IN prep xx True True
# Chennai Chennai PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#                                                               SPACE _SP
#      False False
# - - PUNCT : punct - False False
# Built build VERB VBN ROOT Xxxxx True False
# a a DET DT det x True True
# VR vr NOUN NN nmod XX True False
# teaching teaching NOUN NN nmod xxxx True False
# and and CCONJ CC cc xxx True True
# evaluation evaluation NOUN NN conj xxxx True False
# module module NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# warehouse warehouse NOUN NN pobj xxxx True False
#
#
#                                                               SPACE _SP
#      False False
# employees employee NOUN NNS ROOT xxxx True False
# , , PUNCT , punct , False False
# for for ADP IN prep xxx True True
# a a DET DT det x True True
# tire tire NOUN NN compound xxxx True False
# manufacturing manufacturing NOUN NN compound xxxx True False
# firm firm NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False

# %%
temp = """3D printing
Acting
Aeromodeling
Air sports
Airbrushing
Aircraft Spotting
Airsoft
Airsofting
Amateur astronomy
Amateur geology
Amateur Radio
American football
Animal fancy
Animals/pets/dogs
Antiquing
Antiquities
Aqua-lung
Aquarium (Freshwater & Saltwater)
Archery
Art collecting
Arts
Association football
Astrology
Astronomy
Audiophilia
Australian rules football
Auto audiophilia
Auto racing
Backgammon
Backpacking
Badminton
Base Jumping
Baseball
Basketball
Baton Twirling
Beach Volleyball
Beach/Sun tanning
Beachcombing
Beadwork
Beatboxing
Becoming A Child Advocate
Beekeeping
Bell Ringing
Belly Dancing
Bicycle Polo
Bicycling
Billiards
Bird watching
Birding
Birdwatching
Blacksmithing
Blogging
BMX
Board games
Board sports
BoardGames
Boating
Body Building
Bodybuilding
Bonsai Tree
Book collecting
Bookbinding
Boomerangs
Bowling
Boxing
Brazilian jiu-jitsu
Breakdancing
Brewing Beer
Bridge
Bridge Building
Bringing Food To The Disabled
Building A House For Habitat For Humanity
Building Dollhouses
Bus spotting
Butterfly Watching
Button Collecting
Cake Decorating
Calligraphy
Camping
Candle making
Canoeing
Car Racing
Card collecting
Cartooning
Casino Gambling
Cave Diving
Ceramics
Cheerleading
Chess
Church/church activities
Cigar Smoking
Climbing
Cloud Watching
Coin Collecting
Collecting
Collecting Antiques
Collecting Artwork
Collecting Hats
Collecting Music Albums
Collecting RPM Records
Collecting Sports Cards (Baseball, Football, Basketball, Hockey)
Collecting Swords
Color guard
Coloring
Comic book collecting
Compose Music
Computer activities
Computer programming
Conworlding
Cooking
Cosplay
Cosplaying
Couponing
Crafts
Crafts (unspecified)
Creative writing
Cricket
Crochet
Crocheting
Cross-Stitch
Crossword Puzzles
Cryptography
Curling
Cycling
Dance
Dancing
Darts
Debate
Deltiology (postcard collecting)
Diecast Collectibles
Digital arts
Digital Photography
Disc golf
Do it yourself
Dodgeball
Dog sport
Dolls
Dominoes
Dowsing
Drama
Drawing
Driving
Dumpster Diving
Eating out
Educational Courses
Electronics
Element collecting
Embroidery
Entertaining
Equestrianism
Exercise (aerobics, weights)
Exhibition drill
Falconry
Fast cars
Felting
Fencing
Field hockey
Figure skating
Fire Poi
Fishing
Fishkeeping
Flag Football
Floorball
Floral Arrangements
Flower arranging
Flower collecting and pressing
Fly Tying
Flying
Footbag
Football
Foraging
Foreign language learning
Fossil hunting
Four Wheeling
Freshwater Aquariums
Frisbee Golf – Frolf
Gambling
Games
Gaming (tabletop games and role-playing games)
Garage Saleing
Gardening
Genealogy
Geocaching
Ghost hunting
Glassblowing
Glowsticking
Gnoming
Go
Go Kart Racing
Going to movies
Golf
Golfing
Gongoozling
Graffiti
Grip Strength
Guitar
Gun Collecting
Gunsmithing
Gymnastics
Gyotaku
Handball
Handwriting Analysis
Hang gliding
Herping
Hiking
Home Brewing
Home Repair
Home Theater
Homebrewing
Hooping
Horse riding
Hot air ballooning
Hula Hooping
Hunting
Ice hockey
Ice skating
Iceskating
Illusion
Impersonations
Inline skating
Insect collecting
Internet
Inventing
Jet Engines
Jewelry Making
Jigsaw Puzzles
Jogging
Judo
Juggling
Jukskei
Jump Roping
Kabaddi
Kart racing
Kayaking
Keep A Journal
Kitchen Chemistry
Kite Boarding
Kite flying
Kites
Kitesurfing
Knapping
Knife making
Knife throwing
Knitting
Knotting
Lacemaking
Lacrosse
Lapidary
LARPing
Laser tag
Lasers
Lawn Darts
Learn to Play Poker
Learning A Foreign Language
Learning An Instrument
Learning To Pilot A Plane
Leather crafting
Leathercrafting
Lego building
Legos
Letterboxing
Listening to music
Locksport
Machining
Macramé
Macrame
Magic
Mahjong
Making Model Cars
Marbles
Marksmanship
Martial arts
Matchstick Modeling
Meditation
Metal detecting
Meteorology
Microscopy
Mineral collecting
Model aircraft
Model building
Model Railroading
Model Rockets
Modeling Ships
Models
Motor sports
Motorcycles
Mountain Biking
Mountain Climbing
Mountaineering
Movie and movie memorabilia collecting
Mushroom hunting/Mycology
Musical Instruments
Nail Art
Needlepoint
Netball
Nordic skating
Orienteering
Origami
Owning An Antique Car
Paintball
Painting
Papermache
Papermaking
Parachuting
Paragliding or Power Paragliding
Parkour
People Watching
Photography
Piano
Pigeon racing
Pinochle
Pipe Smoking
Planking
Playing music
Playing musical instruments
Playing team sports
Poker
Pole Dancing
Polo
Pottery
Powerboking
Protesting
Puppetry
Puzzles
Pyrotechnics
Quilting
R/C Boats
R/C Cars
R/C Helicopters
R/C Planes
Racing Pigeons
Racquetball
Radio-controlled car racing
Rafting
Railfans
Rappelling
Rapping
Reading
Reading To The Elderly
Record collecting
Relaxing
Renaissance Faire
Renting movies
Rescuing Abused Or Abandoned Animals
Robotics
Rock balancing
Rock climbing
Rock Collecting
Rockets
Rocking AIDS Babies
Roleplaying
Roller derby
Roller skating
Rugby
Rugby league football
Running
Sailing
Saltwater Aquariums
Sand art
Sand Castles
Scrapbooking
Scuba diving
Sculling or Rowing
Sculpting
Sea glass collecting
Seashell collecting
Self Defense
Sewing
Shark Fishing
Shooting
Shooting sport
Shopping
Shortwave listening
Singing
Singing In Choir
Skateboarding
Skating
Skeet Shooting
Sketching
Skiing
Skimboarding
Sky Diving
Skydiving
Slack Lining
Slacklining
Sleeping
Slingshots
Slot car racing
Snorkeling
Snowboarding
Soap Making
Soapmaking
Soccer
Socializing with friends/neighbors
Speed Cubing (rubix cube)
Speed skating
Spelunkering
Spending time with family/kids
Sports
Squash
Stamp Collecting
Stand-up comedy
Stone collecting
Stone skipping
Storm Chasing
Storytelling
String Figures
Sudoku
Surf Fishing
Surfing
Survival
Swimming
Table football
Table tennis
Taekwondo
Tai chi
Tatting
Taxidermy
Tea Tasting
Tennis
Tesla Coils
Tetris
Textiles
Texting
Tombstone Rubbing
Tool Collecting
Tour skating
Toy Collecting
Train Collecting
Train Spotting
Trainspotting
Traveling
Treasure Hunting
Trekkie
Triathlon
Tutoring Children
TV watching
Ultimate Frisbee
Urban exploration
Vehicle restoration
Video game collecting
Video Games
Video gaming
Videophilia
Vintage cars
Violin
Volleyball
Volunteer
Walking
Warhammer
Watching movies
Watching sporting events
Water sports
Weather Watcher
Web surfing
Weightlifting
Windsurfing
Wine Making
Wingsuit Flying
Wood carving
Woodworking
Working In A Food Pantry
Working on cars
World Record Breaking
Worldbuilding
Wrestling
Writing
Writing Music
Writing Songs
Yo-yoing
Yoga
YoYo
Ziplining
Zumba"""

# %%
#tmp= """ Achievements
#Skills
#Education
#Experience
#Projects
#objective
#"""

# %%
nlp_text=nlp(finalpg[6])

tokens = [token.text for token in nlp_text if not token.is_stop]
for j,i in enumerate(tokens):
  if i.lower()=='hobbies':
    j+=1
    x=tokens[j]
    ans=''
    while (j<len(tokens) or x!='\n'):
      if (nlp(x)[0].pos_ in ['NOUN','VERB'] or x.lower() in temp.lower()):
        ans=ans+x+' '
        if x=='\n':
          break
        if j<len(tokens) and nlp(tokens[j])[0].pos_ == 'SPACE':
          j+=1
        if x=='\n':
          break
        if (nlp(x)[0].pos_=='NOUN' or nlp(x)[0].pos_=='VERB') and j<len(tokens) and nlp(tokens[j])[0].pos_ not in ['NOUN','SPACE','PUNCT']:
          ans=ans+ ','
      j+=1
      if j>=len(tokens) or x=='\n':
        break
      x=tokens[j]
    ans=ans.replace(' ,',',')
    print(ans)
    
    break
# Out:
# Certificate Completion Certified,Network Security explore,technologies ) ) read,chronicles freedom   Member Volleyball ) fighters gold kabaddi ( ) Drawing,Sketching,Worked,Class Representative position Science ) Event
